# %% [markdown]
# # Recipe Content-Based Recommender

# %% [markdown]
# ## Imports and Downloads

# %%
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# !gdown 1zvb2c8buI52xHa-rYJuoRthWx1gFApPD
# !unzip growell-recommendation-dataset.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1zvb2c8buI52xHa-rYJuoRthWx1gFApPD
# To: /content/growell-recommendation-dataset.zip
# 100% 4.88k/4.88k [00:00<00:00, 14.0MB/s]
# Archive:  growell-recommendation-dataset.zip
#   inflating: recipes.csv
#   inflating: recipes_ingredients.csv
#   inflating: ingredients.csv

# %%
recipes = pd.read_csv('recipes.csv')
ingredients = pd.read_csv('ingredients.csv')
ingredients_recipes = pd.read_csv('recipes_ingredients.csv')

# %%
recipes.head()
# Out:
#                                      id  \
# 0  12893e1a-1d30-47fb-a6ee-8c46e034b437
# 1  256e140d-b6fd-4729-8c5f-92a2cc949d21
# 2  3b66fb82-5ede-4f0f-821b-d5da4d78db5c
# 3  4ae654db-16bb-43da-8f3e-12a9308f4dbe
# 4  4e921465-bc2d-4f6c-83f6-3ccd60153e40
#
#                                              name  target_age  estimated_time  \
# 0                       Sup Sayur Bayam dan Tomat           6              30
# 1                              Chicken Bone Broth           2              30
# 2  Tempe Goreng dengan Sayuran Wortel dan Brokoli          13              30
# 3               Tumis Ayam dengan Tomat dan Tempe          13              30
# 4             Mashed Avocado dan Kentang Panggang          12              60
#
#             ingredients
# 0          wortel|tomat
# 1           ayam|wortel
# 2  wortel|brokoli|tempe
# 3      ayam|tomat|tempe
# 4               kentang

# %%
ingredients.head()
# Out:
#                                      id         name  calories  picture
# 0  02c3c4e5-666f-44e3-a104-5d1c215c0dfc         ayam       133      NaN
# 1  0803dbb8-3f92-4e68-add6-eb56e8dfe872       wortel        48      NaN
# 2  3f02f9e7-e344-43fc-b74e-763a352842e6      kentang        73      NaN
# 3  4393be63-9656-49a0-a974-dd8a088172f8        tomat        21      NaN
# 4  763e08e2-f2f6-4f9b-ab08-a7834b4eabc1  daging sapi       243      NaN

# %%
ingredients_recipes.head()
# Out:
#                                       A                                     B
# 0  0803dbb8-3f92-4e68-add6-eb56e8dfe872  12893e1a-1d30-47fb-a6ee-8c46e034b437
# 1  4393be63-9656-49a0-a974-dd8a088172f8  12893e1a-1d30-47fb-a6ee-8c46e034b437
# 2  02c3c4e5-666f-44e3-a104-5d1c215c0dfc  256e140d-b6fd-4729-8c5f-92a2cc949d21
# 3  0803dbb8-3f92-4e68-add6-eb56e8dfe872  256e140d-b6fd-4729-8c5f-92a2cc949d21
# 4  0803dbb8-3f92-4e68-add6-eb56e8dfe872  3b66fb82-5ede-4f0f-821b-d5da4d78db5c

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Convert Ingredient-Recipe Relation to Dictionary

# %%
ingredients_map = {}

for ingredient, recipe in ingredients_recipes.to_numpy():
  ingredient_name = ingredients[ingredients['id'] == ingredient]['name'].values[0]
  ingredients_map[recipe] = ingredient_name if recipe not in ingredients_map else ingredients_map[recipe] + '|' + ingredient_name

ingredients_map
# Out:
# {'12893e1a-1d30-47fb-a6ee-8c46e034b437': 'wortel|tomat',
#  '256e140d-b6fd-4729-8c5f-92a2cc949d21': 'ayam|wortel',
#  '3b66fb82-5ede-4f0f-821b-d5da4d78db5c': 'wortel|brokoli|tempe',
#  '4ae654db-16bb-43da-8f3e-12a9308f4dbe': 'ayam|tomat|tempe',
#  '4e921465-bc2d-4f6c-83f6-3ccd60153e40': 'kentang',
#  '5a5d6c25-dd72-4a5e-a27a-69f4ed1cc04f': 'jagung|brokoli',
#  '70c7509e-7a39-4949-9f87-b84f0edaa8d0': 'ayam|wortel',
#  '7c7b8c15-0f96-4da1-88ff-172174b0ecbc': 'wortel|telur|brokoli',
#  '810f4de1-e7cb-4395-8545-636df5ab433e': 'daging sapi|jagung',
#  '83387a4d-50ee-4d9a-9a93-86532a652e1c': 'wortel|kentang|brokoli',
#  '8f8a4951-bb15-4478-b533-80f11b0c07de': 'wortel|tomat',
#  'aa68742d-9042-4a4d-8837-37eca799a775': 'kentang|telur',
#  'b4f306f9-cf8d-47c0-ba57-2dfef0db1d78': 'wortel|daging sapi|jagung',
#  'bac3b441-e982-436e-9181-9538c6b45523': 'wortel|ikan|brokoli',
#  'bfd4acec-af8d-4d70-90d6-8309bbbbee8f': 'tomat|brokoli',
#  'c15d53fd-6e4c-4209-bde5-4f95d111ed8c': 'ayam',
#  'd484cbe8-84e0-496f-9dcf-b35ee577746a': 'wortel|telur',
#  'd8d86b7d-a178-49c9-b2e4-104626774b58': 'wortel|telur',
#  'e0715743-d18b-41e7-b290-9d1d4b8e4686': 'wortel|kentang|ikan',
#  'ee35eb4e-ac5a-4534-b47a-602bc760ab5c': 'tomat|tempe',
#  'f98d8fbe-c94f-487f-934b-6ba433c67ff6': 'ayam|kentang',
#  'fdbaf820-1055-4fed-ad5e-f0c8df1bdc63': 'wortel|kentang|brokoli'}

# %% [markdown]
# ### Apply Dictionary to DataFrame and Remove Unnecessary Columns

# %%
recipes['ingredients'] = recipes['id'].map(ingredients_map)
recipes.drop(['rating', 'picture', 'how_to', 'tools', 'description', 'created_at', 'updated_at'], axis = 1, inplace = True)

# %%
recipes['ingredients'].str.get_dummies('|').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ayam         22 non-null     int64
#  1   brokoli      22 non-null     int64
#  2   daging sapi  22 non-null     int64
#  3   ikan         22 non-null     int64
#  4   jagung       22 non-null     int64
#  5   kentang      22 non-null     int64
#  6   telur        22 non-null     int64
#  7   tempe        22 non-null     int64
#  8   tomat        22 non-null     int64
#  9   wortel       22 non-null     int64
# dtypes: int64(10)
# memory usage: 1.8 KB

# %% [markdown]
# ## Cosine Similarity

# %%
data = recipes.copy()
data.head()
# Out:
#                                      id  \
# 0  12893e1a-1d30-47fb-a6ee-8c46e034b437
# 1  256e140d-b6fd-4729-8c5f-92a2cc949d21
# 2  3b66fb82-5ede-4f0f-821b-d5da4d78db5c
# 3  4ae654db-16bb-43da-8f3e-12a9308f4dbe
# 4  4e921465-bc2d-4f6c-83f6-3ccd60153e40
#
#                                              name  target_age  estimated_time  \
# 0                       Sup Sayur Bayam dan Tomat           6              30
# 1                              Chicken Bone Broth           2              30
# 2  Tempe Goreng dengan Sayuran Wortel dan Brokoli          13              30
# 3               Tumis Ayam dengan Tomat dan Tempe          13              30
# 4             Mashed Avocado dan Kentang Panggang          12              60
#
#             ingredients
# 0          wortel|tomat
# 1           ayam|wortel
# 2  wortel|brokoli|tempe
# 3      ayam|tomat|tempe
# 4               kentang

# %% [markdown]
# ### Get TF-IDF Based On Recipe Ingredients

# %%
def ingredients_tokenizer(ingredients):
  return ingredients.split('|')

# %%
tf_vectorizer = TfidfVectorizer(tokenizer=ingredients_tokenizer, token_pattern=None)
tf_vectorizer.fit(data['ingredients'])
tf_vectorizer.get_feature_names_out()
# Out:
# array(['ayam', 'brokoli', 'daging sapi', 'ikan', 'jagung', 'kentang',
#        'telur', 'tempe', 'tomat', 'wortel'], dtype=object)

# %%
tfidf_matrix = tf_vectorizer.fit_transform(data['ingredients'])
tfidf_matrix.shape
# Out:
# (22, 10)

# %%
pd.DataFrame(
    tfidf_matrix.todense(),
    columns=tf_vectorizer.get_feature_names_out(),
    index=data.name
).sample(10, axis=1).sample(22, axis=0)
# Out:
#                                                      brokoli      ayam  \
# name
# Mashed Avocado dan Kentang Panggang                 0.000000  0.000000
# Sup Ikan dan Kentang Wortel                         0.000000  0.000000
# Sup Labu dan Ayam                                   0.000000  1.000000
# Kaldu ayam untuk mpasi                              0.000000  0.000000
# Salad Tomat dan Brokoli                             0.659464  0.000000
# Puree Buah                                          0.000000  0.000000
# Tumis Ayam dengan Tomat dan Tempe                   0.000000  0.544256
# Chicken Bone Broth                                  0.000000  0.842851
# Tim Ayam, Nasi, wortel                              0.000000  0.000000
# Sup Jagung Wortel dan Daging Sapi                   0.000000  0.000000
# Ikan Panggang dengan Kentang dan Sayuran Wortel...  0.519077  0.000000
# Sup Sayur Bayam dan Tomat                           0.000000  0.000000
# Telur Rebus dengan Wortel dan Brokoli               0.573618  0.000000
# Telur Dadar dengan Kentang                          0.000000  0.000000
# Puree Tempe dan Tomat                               0.000000  0.000000
# Daging Sapi Panggang dengan Jagung                  0.000000  0.000000
# Puree Sayuran dan Ayam                              0.000000  0.842851
# Puree Sayuran                                       0.612698  0.000000
# Puree Jagung dan Brokoli                            0.598909  0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli      0.549018  0.000000
# Nasi Tim Sayur                                      0.612698  0.000000
# Bubur Ayam dan Ketang                               0.000000  0.730729
#
#                                                       wortel     telur  \
# name
# Mashed Avocado dan Kentang Panggang                 0.000000  0.000000
# Sup Ikan dan Kentang Wortel                         0.371149  0.000000
# Sup Labu dan Ayam                                   0.000000  0.000000
# Kaldu ayam untuk mpasi                              0.509680  0.860364
# Salad Tomat dan Brokoli                             0.000000  0.000000
# Puree Buah                                          0.538147  0.000000
# Tumis Ayam dengan Tomat dan Tempe                   0.000000  0.000000
# Chicken Bone Broth                                  0.538147  0.000000
# Tim Ayam, Nasi, wortel                              0.509680  0.860364
# Sup Jagung Wortel dan Daging Sapi                   0.343125  0.000000
# Ikan Panggang dengan Kentang dan Sayuran Wortel...  0.377795  0.000000
# Sup Sayur Bayam dan Tomat                           0.538147  0.000000
# Telur Rebus dengan Wortel dan Brokoli               0.417491  0.704744
# Telur Dadar dengan Kentang                          0.000000  0.755639
# Puree Tempe dan Tomat                               0.000000  0.000000
# Daging Sapi Panggang dengan Jagung                  0.000000  0.000000
# Puree Sayuran dan Ayam                              0.538147  0.000000
# Puree Sayuran                                       0.445934  0.000000
# Puree Jagung dan Brokoli                            0.000000  0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli      0.399586  0.000000
# Nasi Tim Sayur                                      0.445934  0.000000
# Bubur Ayam dan Ketang                               0.000000  0.000000
#
#                                                        tempe  daging sapi  \
# name
# Mashed Avocado dan Kentang Panggang                 0.000000     0.000000
# Sup Ikan dan Kentang Wortel                         0.000000     0.000000
# Sup Labu dan Ayam                                   0.000000     0.000000
# Kaldu ayam untuk mpasi                              0.000000     0.000000
# Salad Tomat dan Brokoli                             0.000000     0.000000
# Puree Buah                                          0.000000     0.000000
# Tumis Ayam dengan Tomat dan Tempe                   0.638412     0.000000
# Chicken Bone Broth                                  0.000000     0.000000
# Tim Ayam, Nasi, wortel                              0.000000     0.000000
# Sup Jagung Wortel dan Daging Sapi                   0.000000     0.696341
# Ikan Panggang dengan Kentang dan Sayuran Wortel...  0.000000     0.000000
# Sup Sayur Bayam dan Tomat                           0.000000     0.000000
# Telur Rebus dengan Wortel dan Brokoli               0.000000     0.000000
# Telur Dadar dengan Kentang                          0.000000     0.000000
# Puree Tempe dan Tomat                               0.760994     0.000000
# Daging Sapi Panggang dengan Jagung                  0.000000     0.741348
# Puree Sayuran dan Ayam                              0.000000     0.000000
# Puree Sayuran                                       0.000000     0.000000
# Puree Jagung dan Brokoli                            0.000000     0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli      0.734105     0.000000
# Nasi Tim Sayur                                      0.000000     0.000000
# Bubur Ayam dan Ketang                               0.000000     0.000000
#
#                                                       jagung   kentang  \
# name
# Mashed Avocado dan Kentang Panggang                 0.000000  1.000000
# Sup Ikan dan Kentang Wortel                         0.000000  0.543064
# Sup Labu dan Ayam                                   0.000000  0.000000
# Kaldu ayam untuk mpasi                              0.000000  0.000000
# Salad Tomat dan Brokoli                             0.000000  0.000000
# Puree Buah                                          0.000000  0.000000
# Tumis Ayam dengan Tomat dan Tempe                   0.000000  0.000000
# Chicken Bone Broth                                  0.000000  0.000000
# Tim Ayam, Nasi, wortel                              0.000000  0.000000
# Sup Jagung Wortel dan Daging Sapi                   0.630377  0.000000
# Ikan Panggang dengan Kentang dan Sayuran Wortel...  0.000000  0.000000
# Sup Sayur Bayam dan Tomat                           0.000000  0.000000
# Telur Rebus dengan Wortel dan Brokoli               0.000000  0.000000
# Telur Dadar dengan Kentang                          0.000000  0.654988
# Puree Tempe dan Tomat                               0.000000  0.000000
# Daging Sapi Panggang dengan Jagung                  0.671121  0.000000
# Puree Sayuran dan Ayam                              0.000000  0.000000
# Puree Sayuran                                       0.000000  0.652490
# Puree Jagung dan Brokoli                            0.800817  0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli      0.000000  0.000000
# Nasi Tim Sayur                                      0.000000  0.652490
# Bubur Ayam dan Ketang                               0.000000  0.682668
#
#                                                         ikan     tomat
# name
# Mashed Avocado dan Kentang Panggang                 0.000000  0.000000
# Sup Ikan dan Kentang Wortel                         0.753213  0.000000
# Sup Labu dan Ayam                                   0.000000  0.000000
# Kaldu ayam untuk mpasi                              0.000000  0.000000
# Salad Tomat dan Brokoli                             0.000000  0.751736
# Puree Buah                                          0.000000  0.842851
# Tumis Ayam dengan Tomat dan Tempe                   0.000000  0.544256
# Chicken Bone Broth                                  0.000000  0.000000
# Tim Ayam, Nasi, wortel                              0.000000  0.000000
# Sup Jagung Wortel dan Daging Sapi                   0.000000  0.000000
# Ikan Panggang dengan Kentang dan Sayuran Wortel...  0.766700  0.000000
# Sup Sayur Bayam dan Tomat                           0.000000  0.842851
# Telur Rebus dengan Wortel dan Brokoli               0.000000  0.000000
# Telur Dadar dengan Kentang                          0.000000  0.000000
# Puree Tempe dan Tomat                               0.000000  0.648759
# Daging Sapi Panggang dengan Jagung                  0.000000  0.000000
# Puree Sayuran dan Ayam                              0.000000  0.000000
# Puree Sayuran                                       0.000000  0.000000
# Puree Jagung dan Brokoli                            0.000000  0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli      0.000000  0.000000
# Nasi Tim Sayur                                      0.000000  0.000000
# Bubur Ayam dan Ketang                               0.000000  0.000000

# %% [markdown]
# ### Combine Ingredients Data with Estimated Time and Target Age

# %%
estimated_time_arr = data['estimated_time'].values
min_estimated_time = np.min(estimated_time_arr)
max_estimated_time = np.max(estimated_time_arr)
normalized_estimated_time = data['estimated_time'].map(lambda x: (x - min_estimated_time) / (max_estimated_time - min_estimated_time)).values

# %%
target_age_arr = data['target_age'].values
min_target_age = np.min(target_age_arr)
max_target_age = np.max(target_age_arr)
normalized_target_age = data['target_age'].map(lambda x: (x - min_target_age) / (max_target_age - min_target_age)).values

# %%
estimated_time_column = normalized_estimated_time.reshape(-1, 1)
target_age_column = normalized_target_age.reshape(-1, 1)

# %%
tfidf_matrix.todense().shape
# Out:
# (22, 10)

# %%
feature_matrix = np.concatenate([tfidf_matrix.todense(), estimated_time_column, target_age_column], axis=1)
feature_matrix.shape
# Out:
# (22, 12)

# %%
feature_columns = np.concatenate([tf_vectorizer.get_feature_names_out(), np.array(['estimated_time', 'target_age'])])

# %%
pd.DataFrame(
    np.asarray(feature_matrix),
    columns=feature_columns,
    index=data.name
).sample(11, axis=1).sample(22, axis=0)
# Out:
#                                                     daging sapi   brokoli  \
# name
# Chicken Bone Broth                                     0.000000  0.000000
# Tim Ayam, Nasi, wortel                                 0.000000  0.000000
# Telur Rebus dengan Wortel dan Brokoli                  0.000000  0.573618
# Puree Jagung dan Brokoli                               0.000000  0.598909
# Tumis Ayam dengan Tomat dan Tempe                      0.000000  0.000000
# Telur Dadar dengan Kentang                             0.000000  0.000000
# Sup Labu dan Ayam                                      0.000000  0.000000
# Bubur Ayam dan Ketang                                  0.000000  0.000000
# Sup Jagung Wortel dan Daging Sapi                      0.696341  0.000000
# Sup Sayur Bayam dan Tomat                              0.000000  0.000000
# Puree Tempe dan Tomat                                  0.000000  0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli         0.000000  0.549018
# Kaldu ayam untuk mpasi                                 0.000000  0.000000
# Sup Ikan dan Kentang Wortel                            0.000000  0.000000
# Salad Tomat dan Brokoli                                0.000000  0.659464
# Puree Sayuran                                          0.000000  0.612698
# Puree Sayuran dan Ayam                                 0.000000  0.000000
# Puree Buah                                             0.000000  0.000000
# Daging Sapi Panggang dengan Jagung                     0.741348  0.000000
# Mashed Avocado dan Kentang Panggang                    0.000000  0.000000
# Nasi Tim Sayur                                         0.000000  0.612698
# Ikan Panggang dengan Kentang dan Sayuran Wortel...     0.000000  0.519077
#
#                                                        tempe     tomat  \
# name
# Chicken Bone Broth                                  0.000000  0.000000
# Tim Ayam, Nasi, wortel                              0.000000  0.000000
# Telur Rebus dengan Wortel dan Brokoli               0.000000  0.000000
# Puree Jagung dan Brokoli                            0.000000  0.000000
# Tumis Ayam dengan Tomat dan Tempe                   0.638412  0.544256
# Telur Dadar dengan Kentang                          0.000000  0.000000
# Sup Labu dan Ayam                                   0.000000  0.000000
# Bubur Ayam dan Ketang                               0.000000  0.000000
# Sup Jagung Wortel dan Daging Sapi                   0.000000  0.000000
# Sup Sayur Bayam dan Tomat                           0.000000  0.842851
# Puree Tempe dan Tomat                               0.760994  0.648759
# Tempe Goreng dengan Sayuran Wortel dan Brokoli      0.734105  0.000000
# Kaldu ayam untuk mpasi                              0.000000  0.000000
# Sup Ikan dan Kentang Wortel                         0.000000  0.000000
# Salad Tomat dan Brokoli                             0.000000  0.751736
# Puree Sayuran                                       0.000000  0.000000
# Puree Sayuran dan Ayam                              0.000000  0.000000
# Puree Buah                                          0.000000  0.842851
# Daging Sapi Panggang dengan Jagung                  0.000000  0.000000
# Mashed Avocado dan Kentang Panggang                 0.000000  0.000000
# Nasi Tim Sayur                                      0.000000  0.000000
# Ikan Panggang dengan Kentang dan Sayuran Wortel...  0.000000  0.000000
#
#                                                        telur  estimated_time  \
# name
# Chicken Bone Broth                                  0.000000        0.000000
# Tim Ayam, Nasi, wortel                              0.860364        1.000000
# Telur Rebus dengan Wortel dan Brokoli               0.704744        0.000000
# Puree Jagung dan Brokoli                            0.000000        0.000000
# Tumis Ayam dengan Tomat dan Tempe                   0.000000        0.000000
# Telur Dadar dengan Kentang                          0.755639        0.000000
# Sup Labu dan Ayam                                   0.000000        0.000000
# Bubur Ayam dan Ketang                               0.000000        0.000000
# Sup Jagung Wortel dan Daging Sapi                   0.000000        0.000000
# Sup Sayur Bayam dan Tomat                           0.000000        0.000000
# Puree Tempe dan Tomat                               0.000000        0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli      0.000000        0.000000
# Kaldu ayam untuk mpasi                              0.860364        0.000000
# Sup Ikan dan Kentang Wortel                         0.000000        0.000000
# Salad Tomat dan Brokoli                             0.000000        0.000000
# Puree Sayuran                                       0.000000        0.000000
# Puree Sayuran dan Ayam                              0.000000        0.000000
# Puree Buah                                          0.000000        0.000000
# Daging Sapi Panggang dengan Jagung                  0.000000        0.000000
# Mashed Avocado dan Kentang Panggang                 0.000000        0.333333
# Nasi Tim Sayur                                      0.000000        0.000000
# Ikan Panggang dengan Kentang dan Sayuran Wortel...  0.000000        0.000000
#
#                                                       wortel      ikan  \
# name
# Chicken Bone Broth                                  0.538147  0.000000
# Tim Ayam, Nasi, wortel                              0.509680  0.000000
# Telur Rebus dengan Wortel dan Brokoli               0.417491  0.000000
# Puree Jagung dan Brokoli                            0.000000  0.000000
# Tumis Ayam dengan Tomat dan Tempe                   0.000000  0.000000
# Telur Dadar dengan Kentang                          0.000000  0.000000
# Sup Labu dan Ayam                                   0.000000  0.000000
# Bubur Ayam dan Ketang                               0.000000  0.000000
# Sup Jagung Wortel dan Daging Sapi                   0.343125  0.000000
# Sup Sayur Bayam dan Tomat                           0.538147  0.000000
# Puree Tempe dan Tomat                               0.000000  0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli      0.399586  0.000000
# Kaldu ayam untuk mpasi                              0.509680  0.000000
# Sup Ikan dan Kentang Wortel                         0.371149  0.753213
# Salad Tomat dan Brokoli                             0.000000  0.000000
# Puree Sayuran                                       0.445934  0.000000
# Puree Sayuran dan Ayam                              0.538147  0.000000
# Puree Buah                                          0.538147  0.000000
# Daging Sapi Panggang dengan Jagung                  0.000000  0.000000
# Mashed Avocado dan Kentang Panggang                 0.000000  0.000000
# Nasi Tim Sayur                                      0.445934  0.000000
# Ikan Panggang dengan Kentang dan Sayuran Wortel...  0.377795  0.766700
#
#                                                     target_age      ayam  \
# name
# Chicken Bone Broth                                    0.000000  0.842851
# Tim Ayam, Nasi, wortel                                0.000000  0.000000
# Telur Rebus dengan Wortel dan Brokoli                 0.545455  0.000000
# Puree Jagung dan Brokoli                              0.363636  0.000000
# Tumis Ayam dengan Tomat dan Tempe                     1.000000  0.544256
# Telur Dadar dengan Kentang                            0.545455  0.000000
# Sup Labu dan Ayam                                     0.363636  1.000000
# Bubur Ayam dan Ketang                                 0.363636  0.730729
# Sup Jagung Wortel dan Daging Sapi                     0.363636  0.000000
# Sup Sayur Bayam dan Tomat                             0.363636  0.000000
# Puree Tempe dan Tomat                                 0.181818  0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli        1.000000  0.000000
# Kaldu ayam untuk mpasi                                0.090909  0.000000
# Sup Ikan dan Kentang Wortel                           0.363636  0.000000
# Salad Tomat dan Brokoli                               1.000000  0.000000
# Puree Sayuran                                         0.181818  0.000000
# Puree Sayuran dan Ayam                                0.363636  0.842851
# Puree Buah                                            0.181818  0.000000
# Daging Sapi Panggang dengan Jagung                    1.000000  0.000000
# Mashed Avocado dan Kentang Panggang                   0.909091  0.000000
# Nasi Tim Sayur                                        0.909091  0.000000
# Ikan Panggang dengan Kentang dan Sayuran Wortel...    1.000000  0.000000
#
#                                                      kentang
# name
# Chicken Bone Broth                                  0.000000
# Tim Ayam, Nasi, wortel                              0.000000
# Telur Rebus dengan Wortel dan Brokoli               0.000000
# Puree Jagung dan Brokoli                            0.000000
# Tumis Ayam dengan Tomat dan Tempe                   0.000000
# Telur Dadar dengan Kentang                          0.654988
# Sup Labu dan Ayam                                   0.000000
# Bubur Ayam dan Ketang                               0.682668
# Sup Jagung Wortel dan Daging Sapi                   0.000000
# Sup Sayur Bayam dan Tomat                           0.000000
# Puree Tempe dan Tomat                               0.000000
# Tempe Goreng dengan Sayuran Wortel dan Brokoli      0.000000
# Kaldu ayam untuk mpasi                              0.000000
# Sup Ikan dan Kentang Wortel                         0.543064
# Salad Tomat dan Brokoli                             0.000000
# Puree Sayuran                                       0.652490
# Puree Sayuran dan Ayam                              0.000000
# Puree Buah                                          0.000000
# Daging Sapi Panggang dengan Jagung                  0.000000
# Mashed Avocado dan Kentang Panggang                 1.000000
# Nasi Tim Sayur                                      0.652490
# Ikan Panggang dengan Kentang dan Sayuran Wortel...  0.000000

# %% [markdown]
# ### Apply Cosine Similarity

# %%
cosine_sim = cosine_similarity(np.asarray(feature_matrix))
cosine_sim.shape
# Out:
# (22, 22)

# %%
cosine_sim_df = pd.DataFrame(cosine_sim, index=data['name'], columns=data['name'])
print('Shape:', cosine_sim_df.shape)

cosine_sim_df.sample(5, axis=1).sample(10, axis=0)
# Out:
# Shape: (22, 22)
# name                                   Telur Rebus dengan Wortel dan Brokoli  \
# name
# Sup Sayur Bayam dan Tomat                                           0.349007
# Tim Ayam, Nasi, wortel                                              0.508484
# Puree Buah                                                          0.279716
# Puree Jagung dan Brokoli                                            0.447083
# Chicken Bone Broth                                                  0.197238
# Sup Jagung Wortel dan Daging Sapi                                   0.281833
# Telur Rebus dengan Wortel dan Brokoli                               1.000000
# Puree Tempe dan Tomat                                               0.085660
# Daging Sapi Panggang dengan Jagung                                  0.338600
# Tumis Ayam dengan Tomat dan Tempe                                   0.338600
#
# name                                   Sup Sayur Bayam dan Tomat  \
# name
# Sup Sayur Bayam dan Tomat                               1.000000
# Tim Ayam, Nasi, wortel                                  0.182270
# Puree Buah                                              0.985767
# Puree Jagung dan Brokoli                                0.116788
# Chicken Bone Broth                                      0.272166
# Sup Jagung Wortel dan Daging Sapi                       0.279875
# Telur Rebus dengan Wortel dan Brokoli                   0.349007
# Puree Tempe dan Tomat                                   0.566730
# Daging Sapi Panggang dengan Jagung                      0.241649
# Tumis Ayam dengan Tomat dan Tempe                       0.546489
#
# name                                   Tempe Goreng dengan Sayuran Wortel dan Brokoli  \
# name
# Sup Sayur Bayam dan Tomat                                                    0.384548
# Tim Ayam, Nasi, wortel                                                       0.101831
# Puree Buah                                                                   0.276092
# Puree Jagung dan Brokoli                                                     0.460156
# Chicken Bone Broth                                                           0.152053
# Sup Jagung Wortel dan Daging Sapi                                            0.332762
# Telur Rebus dengan Wortel dan Brokoli                                        0.637653
# Puree Tempe dan Tomat                                                        0.515144
# Daging Sapi Panggang dengan Jagung                                           0.500000
# Tumis Ayam dengan Tomat dan Tempe                                            0.734331
#
# name                                   Sup Ikan dan Kentang Wortel  \
# name
# Sup Sayur Bayam dan Tomat                                 0.293194
# Tim Ayam, Nasi, wortel                                    0.125708
# Puree Buah                                                0.245813
# Puree Jagung dan Brokoli                                  0.116788
# Chicken Bone Broth                                        0.187707
# Sup Jagung Wortel dan Daging Sapi                         0.229266
# Telur Rebus dengan Wortel dan Brokoli                     0.291485
# Puree Tempe dan Tomat                                     0.061133
# Daging Sapi Panggang dengan Jagung                        0.241649
# Tumis Ayam dengan Tomat dan Tempe                         0.241649
#
# name                                   Sup Jagung Wortel dan Daging Sapi
# name
# Sup Sayur Bayam dan Tomat                                       0.279875
# Tim Ayam, Nasi, wortel                                          0.116216
# Puree Buah                                                      0.231868
# Puree Jagung dan Brokoli                                        0.562648
# Chicken Bone Broth                                              0.173534
# Sup Jagung Wortel dan Daging Sapi                               1.000000
# Telur Rebus dengan Wortel dan Brokoli                           0.281833
# Puree Tempe dan Tomat                                           0.061133
# Daging Sapi Panggang dengan Jagung                              0.865839
# Tumis Ayam dengan Tomat dan Tempe                               0.241649

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Use Cosine Similarity Result to Get Recommendations

# %%
items = data.iloc[:, 1:]
items
# Out:
#                                                  name  target_age  \
# 0                           Sup Sayur Bayam dan Tomat           6
# 1                                  Chicken Bone Broth           2
# 2      Tempe Goreng dengan Sayuran Wortel dan Brokoli          13
# 3                   Tumis Ayam dengan Tomat dan Tempe          13
# 4                 Mashed Avocado dan Kentang Panggang          12
# 5                            Puree Jagung dan Brokoli           6
# 6                              Puree Sayuran dan Ayam           6
# 7               Telur Rebus dengan Wortel dan Brokoli           8
# 8                  Daging Sapi Panggang dengan Jagung          13
# 9                                      Nasi Tim Sayur          12
# 10                                         Puree Buah           4
# 11                         Telur Dadar dengan Kentang           8
# 12                  Sup Jagung Wortel dan Daging Sapi           6
# 13  Ikan Panggang dengan Kentang dan Sayuran Worte...          13
# 14                            Salad Tomat dan Brokoli          13
# 15                                  Sup Labu dan Ayam           6
# 16                             Kaldu ayam untuk mpasi           3
# 17                             Tim Ayam, Nasi, wortel           2
# 18                        Sup Ikan dan Kentang Wortel           6
# 19                              Puree Tempe dan Tomat           4
# 20                              Bubur Ayam dan Ketang           6
# 21                                      Puree Sayuran           4
#
#     estimated_time                ingredients
# 0               30               wortel|tomat
# 1               30                ayam|wortel
# 2               30       wortel|brokoli|tempe
# 3               30           ayam|tomat|tempe
# 4               60                    kentang
# 5               30             jagung|brokoli
# 6               30                ayam|wortel
# 7               30       wortel|telur|brokoli
# 8               30         daging sapi|jagung
# 9               30     wortel|kentang|brokoli
# 10              30               wortel|tomat
# 11              30              kentang|telur
# 12              30  wortel|daging sapi|jagung
# 13              30        wortel|ikan|brokoli
# 14              30              tomat|brokoli
# 15              30                       ayam
# 16              30               wortel|telur
# 17             120               wortel|telur
# 18              30        wortel|kentang|ikan
# 19              30                tomat|tempe
# 20              30               ayam|kentang
# 21              30     wortel|kentang|brokoli

# %%
def recipe_recommendations(recipe_name, similarity_data=cosine_sim_df, items=items, k=5):
    index = similarity_data.loc[:,recipe_name].to_numpy().argpartition(range(-1, -k, -1))
    closest = similarity_data.columns[index[-1:-(k+2):-1]]
    closest = closest.drop(recipe_name, errors='ignore')
    return pd.DataFrame(closest).merge(items).head(k)

# %%
sample = items.name.sample(1).iloc[0]
items[items['name'] == sample]
# Out:
#                  name  target_age  estimated_time  ingredients
# 1  Chicken Bone Broth           2              30  ayam|wortel

# %%
recipe_recommendations(sample)
# Out:
#                                 name  target_age  estimated_time  \
# 0             Puree Sayuran dan Ayam           6              30
# 1                  Sup Labu dan Ayam           6              30
# 2              Bubur Ayam dan Ketang           6              30
# 3  Tumis Ayam dengan Tomat dan Tempe          13              30
# 4                         Puree Buah           4              30
#
#         ingredients
# 0       ayam|wortel
# 1              ayam
# 2      ayam|kentang
# 3  ayam|tomat|tempe
# 4      wortel|tomat

# %% [markdown]
# ## Export to CSV

# %%
data.to_csv('recipes_data.csv')
cosine_sim_df.to_csv('recipe_similarity.csv')

# %% [markdown]
# ## Load Similarity Data

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load CSV

# %%
recipes_df = pd.read_csv('recipes_data.csv')
sim_df = pd.read_csv('recipe_similarity.csv')
sim_df = pd.DataFrame(sim_df.values[:, 1:], index=recipes_df['id'], columns=recipes_df['id'])
# sim_df.sample(5, axis=1).sample(10, axis=0)
# Out:
# id                                   7c7b8c15-0f96-4da1-88ff-172174b0ecbc  \
# id
# 810f4de1-e7cb-4395-8545-636df5ab433e                               0.3386
# b4f306f9-cf8d-47c0-ba57-2dfef0db1d78                             0.281833
# bac3b441-e982-436e-9181-9538c6b45523                             0.621345
# 4e921465-bc2d-4f6c-83f6-3ccd60153e40                             0.312739
# d8d86b7d-a178-49c9-b2e4-104626774b58                             0.508484
# e0715743-d18b-41e7-b290-9d1d4b8e4686                             0.291485
# aa68742d-9042-4a4d-8837-37eca799a775                             0.639722
# ee35eb4e-ac5a-4534-b47a-602bc760ab5c                              0.08566
# 8f8a4951-bb15-4478-b533-80f11b0c07de                             0.279716
# d484cbe8-84e0-496f-9dcf-b35ee577746a                             0.759505
#
# id                                   8f8a4951-bb15-4478-b533-80f11b0c07de  \
# id
# 810f4de1-e7cb-4395-8545-636df5ab433e                             0.126491
# b4f306f9-cf8d-47c0-ba57-2dfef0db1d78                             0.231868
# bac3b441-e982-436e-9181-9538c6b45523                             0.267934
# 4e921465-bc2d-4f6c-83f6-3ccd60153e40                              0.11683
# d8d86b7d-a178-49c9-b2e4-104626774b58                             0.190819
# e0715743-d18b-41e7-b290-9d1d4b8e4686                             0.245813
# aa68742d-9042-4a4d-8837-37eca799a775                              0.08566
# ee35eb4e-ac5a-4534-b47a-602bc760ab5c                             0.561309
# 8f8a4951-bb15-4478-b533-80f11b0c07de                                  1.0
# d484cbe8-84e0-496f-9dcf-b35ee577746a                             0.284946
#
# id                                   f98d8fbe-c94f-487f-934b-6ba433c67ff6  \
# id
# 810f4de1-e7cb-4395-8545-636df5ab433e                             0.241649
# b4f306f9-cf8d-47c0-ba57-2dfef0db1d78                             0.116788
# bac3b441-e982-436e-9181-9538c6b45523                             0.241649
# 4e921465-bc2d-4f6c-83f6-3ccd60153e40                             0.684101
# d8d86b7d-a178-49c9-b2e4-104626774b58                                  0.0
# e0715743-d18b-41e7-b290-9d1d4b8e4686                             0.444224
# aa68742d-9042-4a4d-8837-37eca799a775                             0.532552
# ee35eb4e-ac5a-4534-b47a-602bc760ab5c                             0.061133
# 8f8a4951-bb15-4478-b533-80f11b0c07de                             0.061133
# d484cbe8-84e0-496f-9dcf-b35ee577746a                              0.03094
#
# id                                   810f4de1-e7cb-4395-8545-636df5ab433e  \
# id
# 810f4de1-e7cb-4395-8545-636df5ab433e                                  1.0
# b4f306f9-cf8d-47c0-ba57-2dfef0db1d78                             0.865839
# bac3b441-e982-436e-9181-9538c6b45523                                  0.5
# 4e921465-bc2d-4f6c-83f6-3ccd60153e40                             0.461812
# d8d86b7d-a178-49c9-b2e4-104626774b58                                  0.0
# e0715743-d18b-41e7-b290-9d1d4b8e4686                             0.241649
# aa68742d-9042-4a4d-8837-37eca799a775                               0.3386
# ee35eb4e-ac5a-4534-b47a-602bc760ab5c                             0.126491
# 8f8a4951-bb15-4478-b533-80f11b0c07de                             0.126491
# d484cbe8-84e0-496f-9dcf-b35ee577746a                             0.064018
#
# id                                   c15d53fd-6e4c-4209-bde5-4f95d111ed8c
# id
# 810f4de1-e7cb-4395-8545-636df5ab433e                             0.241649
# b4f306f9-cf8d-47c0-ba57-2dfef0db1d78                             0.116788
# bac3b441-e982-436e-9181-9538c6b45523                             0.241649
# 4e921465-bc2d-4f6c-83f6-3ccd60153e40                             0.223193
# d8d86b7d-a178-49c9-b2e4-104626774b58                                  0.0
# e0715743-d18b-41e7-b290-9d1d4b8e4686                             0.116788
# aa68742d-9042-4a4d-8837-37eca799a775                             0.163644
# ee35eb4e-ac5a-4534-b47a-602bc760ab5c                             0.061133
# 8f8a4951-bb15-4478-b533-80f11b0c07de                             0.061133
# d484cbe8-84e0-496f-9dcf-b35ee577746a                              0.03094

# %%
def recipe_recommendations(recipe_id, similarity_data, k=5):
    index = similarity_data.loc[:,recipe_id].to_numpy().argpartition(range(-1, -k, -1))
    closest = similarity_data.columns[index[-1:-(k+2):-1]]
    closest = closest.drop(recipe_id, errors='ignore')
    return pd.DataFrame(closest)

# %%
# Index 0 is the most similar, index 1 is the second most similar, etc.
print(recipe_recommendations('810f4de1-e7cb-4395-8545-636df5ab433e', sim_df).values.reshape(-1))
# Out:
# ['b4f306f9-cf8d-47c0-ba57-2dfef0db1d78'
#  '5a5d6c25-dd72-4a5e-a27a-69f4ed1cc04f'
#  '3b66fb82-5ede-4f0f-821b-d5da4d78db5c'
#  '4ae654db-16bb-43da-8f3e-12a9308f4dbe'
#  'bfd4acec-af8d-4d70-90d6-8309bbbbee8f']
